# %%
import pandas as pd
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt
import japanize_matplotlib
import seaborn as sns

pd.options.display.max_rows=500
pd.options.display.max_columns=50

# %%
train = pd.read_feather('../data/input/train_data.feather')
oof = np.load('../logs/lgbm_reg02_20191219153718_23.501/oof.npy')
train['oof'] = oof
train['ae'] = np.abs(train['salary'] - train['oof'])

# %%
df = train[train['area'] == '東京都']

# %%
plt.figure(figsize=(16, 5))
plt.plot(df.sort_values(by='salary', ascending=False)['ae'], 'o')

# %%
df.sort_values(by='salary', ascending=False)
# Out:
#           id  position  age area  sex  partner  num_child  education  \
# 12418  12418         4   48  東京都    1        1          2          4
# 9747    9747         4   52  東京都    2        0          0          4
# 12440  12440         3   50  東京都    1        0          0          4
# 15015  15015         3   47  東京都    2        1          2          4
# 16117  16117         2   51  東京都    2        0          0          4
# 8065    8065         2   45  東京都    1        0          0          4
# 4573    4573         2   45  東京都    2        1          2          4
# 7188    7188         2   46  東京都    1        1          5          4
# 266      266         2   34  東京都    1        0          0          4
# 8698    8698         3   54  東京都    1        0          0          3
# 11419  11419         4   45  東京都    2        1          2          2
# 7769    7769         2   42  東京都    1        1          1          4
# 12076  12076         2   49  東京都    2        0          0          3
# ...
